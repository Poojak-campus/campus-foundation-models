# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-161e3a11-6119-464e-be4e-e715dec100ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-161e3a11-6119-464e-be4e-e715dec100ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'P1 model.zip', 'p1_synthetic_train.csv', 'sample_data']

# %%
import pandas as pd

train = pd.read_csv('/content/p1_synthetic_train.csv')

print(train.head())
print(train.columns)
print(train.shape)
# Out:
#   learner_id   concept_id assessment_id  mastery_score  decay_rate  \
# 0  LNS_32520  CNC_375(30)   ASM_3922(1)            0.0    0.105828
# 1  LNS_46546  CNC_784(45)   ASM_9417(0)            1.0    0.102853
# 2  LNS_32689  CNC_440(19)   ASM_1649(2)            1.0    0.029029
# 3  LNS_08112  CNC_112(45)   ASM_4454(2)            NaN    0.018984
# 4  LNS_26329  CNC_734(21)   ASM_8719(1)            0.0    0.045980
#
#    difficulty  response_correct  bloom_tier         timestamp
# 0    0.339722                 0           1  01-01-2026 02:50
# 1    0.667204                 1           4  01-01-2026 03:00
# 2    0.529326                 0           4  01-01-2026 02:54
# 3    0.746806                 0           2  01-01-2026 04:59
# 4    0.301946                 0           2  01-01-2026 02:44
# Index(['learner_id', 'concept_id', 'assessment_id', 'mastery_score',
#        'decay_rate', 'difficulty', 'response_correct', 'bloom_tier',
#        'timestamp'],
#       dtype='object')
# ...

# %%
print(train.columns)
# Out:
# Index(['learner_id', 'concept_id', 'assessment_id', 'mastery_score',
#        'decay_rate', 'difficulty', 'response_correct', 'bloom_tier',
#        'timestamp'],
#       dtype='object')

# %%
print(train['mastery_score'].isna().sum())
# Out:
# 5371

# %%
print(train['mastery_score'].head(20))
# Out:
# 0     0.0
# 1     1.0
# 2     1.0
# 3     NaN
# 4     0.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    NaN
# 14    1.0
# 15    NaN
# 16    1.0
# 17    0.0
# 18    1.0
# 19    0.0
# Name: mastery_score, dtype: float64

# %%
train = train.dropna(subset=['mastery_score'])

# %%
print(train['mastery_score'].isna().sum())
# Out:
# 0

# %%
features = [
    'decay_rate',
    'difficulty',
    'response_correct',
    'bloom_tier'
]

print(train[features].isna().sum())
# Out:
# decay_rate          0
# difficulty          0
# response_correct    0
# bloom_tier          0
# dtype: int64

# %%
X_train = train[features]
y_train = train['mastery_score']

model.fit(X_train, y_train)

print("Training completed")
# Out:
# Training completed

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-04f8a70a-4288-4ec1-bb8e-f43ec21a9f08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04f8a70a-4288-4ec1-bb8e-f43ec21a9f08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'P1 model.zip', 'p1_synthetic_train.csv', 'p1_synthetic_test.csv', 'sample_data']

# %%
import pandas as pd

test = pd.read_csv('/content/p1_synthetic_test.csv')

print(test.shape)
# Out:
# (7500, 9)

# %%
test = test.dropna(
    subset=[
        'decay_rate',
        'difficulty',
        'response_correct',
        'bloom_tier',
        'mastery_score'
    ]
)

# %%
X_test = test[features]
y_test = test['mastery_score']

pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, pred)

print("Accuracy:", acc)
# Out:
# Accuracy: 0.8267272442425192

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, pred)

print("F1 Score:", f1)
# Out:
# F1 Score: 0.9043914246196404
